# %% [markdown]
# # Librerías

# %%
# !pip install category_encoders
# Out:
# ...
#      |████████████████████████████████| 102kB 8.3MB/s
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import category_encoders as ce
from sklearn.metrics import classification_report, confusion_matrix, roc_curve
from sklearn.linear_model import Ridge
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold, GridSearchCV, train_test_split, cross_val_score
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1 Lectura de los datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/laar19/machine-learning/master/aprendizaje%20supervizado/datos/Telco-Customer-Churn.csv"
data = pd.read_csv(url)
data["TotalCharges"] = pd.to_numeric(data["TotalCharges"], errors="coerce")

print(data.shape) # Retorna las dimensiones del dataframe (filas y columnas)
data.head()       # Por defecto, imprime las 5 primeras filas
# Out:
# (7043, 21)
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95      1889.50     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Características de los datos

# %%
num_clientes_perdidos = 0
num_clientes_activos = 0
for i in data.Churn:
    if i == "No":
        num_clientes_perdidos += 1
    else:
        num_clientes_activos += 1

print("Cantidad de clientes perdidos: ", num_clientes_perdidos)
print("Cantidad de clientes activos:  ", num_clientes_activos, "\n")

data.info()

sns.set_style("whitegrid")
sns.countplot(x="Churn", data=data)
# Out:
# Cantidad de clientes perdidos:  5174
# Cantidad de clientes activos:   1869
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# ...

# %% [markdown]
# ## Revisando datos nulos

# %%
data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# ## Dimensiones del DataFrame

# %%
data.shape
# Out:
# (7043, 21)

# %% [markdown]
# # 2 Preparación de los datos

# %% [markdown]
# ## Remueve la columna customerID

# %%
data = data.drop("customerID", axis=1)

# %% [markdown]
# ## Tipo de dato por variable

# %%
print(data.dtypes)
print("\nSólo 3 columnas son numéricas")
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object
#
# Sólo 3 columnas son numéricas

# %% [markdown]
# ## Estadísticas de las variables numéricas

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# ## Reemplaza los datos en blanco por la media

# %%
data["TotalCharges"].fillna(2283.300441, inplace=True)

# %% [markdown]
# ## Visualización de los datos numéricos

# %%
sns.pairplot(data)

# %% [markdown]
# ## Características de las variables categóricas

# %% [markdown]
# ### Variable gender

# %%
sns.catplot(x="gender", kind="count", palette="ch:.25", data=data)

# %% [markdown]
# ### Variable Partner

# %%
sns.catplot(x="Partner", kind="count", palette="ch:.24", data=data)

# %% [markdown]
# ### Variable Dependents

# %%
sns.catplot(x="Dependents", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable PhoneService

# %%
sns.catplot(x="PhoneService", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable MultipleLines

# %%
sns.catplot(x="MultipleLines", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable InternetService

# %%
sns.catplot(x="InternetService", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable OnlineSecurity

# %%
sns.catplot(x="OnlineSecurity", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable OnlineBackup

# %%
sns.catplot(x="OnlineBackup", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable DeviceProtection

# %%
sns.catplot(x="DeviceProtection", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable TechSupport

# %%
sns.catplot(x="TechSupport", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable StreamingTV

# %%
sns.catplot(x="StreamingTV", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable StreamingMovies

# %%
sns.catplot(x="StreamingMovies", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable Contract

# %%
sns.catplot(x="Contract", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable PaperlessBilling

# %%
sns.catplot(x="PaperlessBilling", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable PaymentMethod

# %%
sns.catplot(x="PaymentMethod", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ### Variable Churn

# %%
sns.catplot(x="Churn", kind="count", palette="ch:.20", data=data)

# %% [markdown]
# ## Transforma los valores de las columnas categóricas a nominales

# %%
churn = pd.get_dummies(data["Churn"], drop_first=True)
print(churn.head())
data["Churn"] = churn

X, y = data.iloc[0:data.shape[0], 0:(data.shape[1]-1)].copy(), data.Churn.copy()

# Datos Categóricos
X_cat = X.select_dtypes(include="object").copy()
X_num = X.select_dtypes(exclude="object").copy()

# Transforma los datos categóricos usando Binary Encoding
encoder = ce.BinaryEncoder(X_cat)
X_cat_num = encoder.fit_transform(X_cat)

# Uniendo los datos numéricos y los categóricos (transformados a numéricos)
X = result = X_num.join(X_cat_num, how="outer")

print(X.head())
# Out:
#    Yes
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
#    SeniorCitizen  tenure  ...  PaymentMethod_1  PaymentMethod_2
# 0              0       1  ...                0                1
# 1              0      34  ...                1                0
# 2              0       2  ...                1                0
# 3              0      45  ...                1                1
# 4              0       2  ...                0                1
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Divide los datos

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.30)

# %% [markdown]
# ## Escala los datos

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
ridge = Ridge().fit(X_train_scaled, y_train)
X_test_scaled = scaler.transform(X_test)
ridge.score(X_test_scaled, y_test)
# Out:
# 0.2567935528881745

# %% [markdown]
# # 3 Entrenamiento y evaluación del modelo

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

modelo1 = SVC(probability=True)
modelo1.fit(X_train_scaled, y_train)
print("test-set score:                   {:.3f}".format(modelo1.score(X_test, y_test)))
# Out:
# test-set score:                   0.738

# %% [markdown]
# ### SVM con validación cruzada

# %%
modelo2 = SVC(probability=True)
scores = cross_val_score(modelo2, X_train_scaled, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()*2))
# Out:
# Accuracy: 0.80 (+/- 0.03)

# %% [markdown]
# ### SVM con GridSearchCV

# %%
modelo3 = SVC(probability=True)
param_grid = {"C":np.logspace(-3, 3, 13), "class_weight":["balanced", None]}
grid = GridSearchCV(estimator=modelo3, param_grid=param_grid, scoring="accuracy", cv=10, return_train_score=True)
grid.fit(X_train_scaled, y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
parametros3 = grid.best_params_
print("best parameters:                  ", parametros3)
print("test-set score:                   {:.3f}".format(grid.score(X_test, y_test)))
# Out:
# best mean cross-validation score: 0.800
# best parameters:                   {'C': 100.0, 'class_weight': None}
# test-set score:                   0.262

# %% [markdown]
# ### SVM con kfold y shuffling

# %%
modelo4 = SVC(probability=True)
kfold = KFold(n_splits=10, random_state=5, shuffle=True)
param_grid = {"C":np.logspace(-3, 3, 13), "class_weight":["balanced", None]}
grid = GridSearchCV(estimator=modelo4, param_grid=param_grid, scoring="accuracy", cv=kfold, return_train_score=True)
grid.fit(X_train_scaled, y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
parametros4 = grid.best_params_
print("best parameters:                  ", parametros4)
print("test-set score:                   {:.3f}".format(grid.score(X_test, y_test)))
# Out:
# best mean cross-validation score: 0.801
# best parameters:                   {'C': 3.1622776601683795, 'class_weight': None}
# test-set score:                   0.262

# %% [markdown]
# # 4 Definiendo los mejores parámetros

# %% [markdown]
# ### SVM con parámetros optimizados con GridSearchCV

# %%
modelo3 = SVC(C=parametros3["C"], class_weight=parametros3["class_weight"], probability=True)
modelo3.fit(X_train_scaled, y_train)
# Out:
# SVC(C=100.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=True, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ### SVM con parámetros optimizados con kfold y shuffling

# %%
modelo4 = SVC(C=parametros3["C"], class_weight=parametros3["class_weight"], probability=True)
modelo4.fit(X_train_scaled, y_train)
# Out:
# SVC(C=100.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=True, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# # 5 Predicciones

# %% [markdown]
# ## Sin optimizar

# %%
predicciones1 = modelo1.predict(X_test_scaled)
print("Reporte de clasificación:\n", classification_report(y_test, predicciones1))
print("Matriz de confusión:\n", confusion_matrix(y_test, predicciones1))

# Datos para ROC curve
preds1 = modelo1.predict_proba(X_test_scaled)[:, 1]
fpr1, tpr1, thresholds = roc_curve(y_test, preds1)
# Out:
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      1560
#            1       0.66      0.50      0.57       553
#
#     accuracy                           0.80      2113
#    macro avg       0.75      0.70      0.72      2113
# weighted avg       0.79      0.80      0.79      2113
#
# Matriz de confusión:
#  [[1418  142]
#  [ 279  274]]

# %% [markdown]
# ## Optimizada con GridSearchCV

# %%
predicciones3 = modelo3.predict(X_test_scaled)
print("Reporte de clasificación:\n", classification_report(y_test, predicciones3))
print("Matriz de confusión:\n", confusion_matrix(y_test, predicciones3))

# Datos para ROC curve
preds3 = modelo3.predict_proba(X_test_scaled)[:, 1]
fpr3, tpr3, thresholds = roc_curve(y_test, preds3)
# Out:
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1560
#            1       0.63      0.52      0.57       553
#
#     accuracy                           0.79      2113
#    macro avg       0.73      0.71      0.72      2113
# weighted avg       0.78      0.79      0.79      2113
#
# Matriz de confusión:
#  [[1390  170]
#  [ 266  287]]

# %% [markdown]
# ## Optimizada con Kfold

# %%
predicciones4 = modelo4.predict(X_test_scaled)
print("Reporte de clasificación:\n", classification_report(y_test, predicciones4))
print("Matriz de confusión:\n", confusion_matrix(y_test, predicciones4))

# Datos para ROC curve
preds4 = modelo4.predict_proba(X_test_scaled)[:, 1]
fpr4, tpr4, thresholds = roc_curve(y_test, preds4)
# Out:
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1560
#            1       0.63      0.52      0.57       553
#
#     accuracy                           0.79      2113
#    macro avg       0.73      0.71      0.72      2113
# weighted avg       0.78      0.79      0.79      2113
#
# Matriz de confusión:
#  [[1390  170]
#  [ 266  287]]

# %% [markdown]
# # Gráfica

# %%
plt.figure(figsize=(15, 10))
plt.plot([0, 1], [0, 1], "k--")
plt.plot(fpr1, tpr1, label="Sin Optimizar")
plt.plot(fpr3, tpr3, label="Optimizada con GridSearchCV")
plt.plot(fpr4, tpr4, label="Optimizada con Kfold")
plt.xlabel("")
plt.ylabel("")
plt.title("ROC curve")
plt.legend(loc="best")
plt.show()
